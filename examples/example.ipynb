# %%
from fit_abundance import fit_final
import pandas as pd

# %%
galaxy_data = pd.read_csv("examples/data_NGC0309.csv")

name = galaxy_data["galaxy"].iloc[0]
ra0 = galaxy_data["ra0"].iloc[0]
dec0 = galaxy_data["dec0"].iloc[0]
pa = galaxy_data["pa"].iloc[0]
ba = galaxy_data["ba"].iloc[0]
re = galaxy_data["re"].iloc[0]
d = galaxy_data["dist"].iloc[0]

# %%
flux = pd.read_csv("examples/HII.NGC0309.flux_elines.csv")

ra = flux["RA"]
dec = flux["DEC"]
EWHa = flux["EWHa6562"]
HIIREGID = flux["HIIREGID"]

Hb4861 = flux["fluxHb4861"]
eHb4861 = flux["e_fluxHb4861"]

OIII5006 = flux["fluxOIII5006"]
eOIII5006 = flux["e_fluxOIII5006"]

Ha6562 = flux["fluxHa6562"]
eHa6562 = flux["e_fluxHa6562"]

NII6583 = flux["fluxNII6583"]
eNII6583 = flux["e_fluxNII6583"]

SII6716 = flux["fluxSII6716"]
eSII6716 = flux["e_fluxSII6716"]

SII6730 = flux["fluxSII6730"]
eSII6730 = flux["e_fluxSII6730"]

# %%
results = fit_final(
    name, HIIREGID, ra, ra0, dec, dec0, pa, ba, d, re, EWHa,
    Hb4861, eHb4861, Ha6562, eHa6562, OIII5006, eOIII5006,
    NII6583, eNII6583, SII6716, eSII6716, SII6730, eSII6730,
    calibrator=1,
    criterion="KA03",
    show_graph=True
)
# Out:
# /home/af/Desktop/fit_oh_cardoso_2025/fit_abundance/abundance.py:101: RuntimeWarning: invalid value encountered in log10
#   excess = (np.log10(2.86) - np.log10(Ha6562/Hb4861)) / (0.4 * (av_Ha6562 - av_Hb4861))
# /home/af/Desktop/fit_oh_cardoso_2025/fit_abundance/abundance.py:106: RuntimeWarning: invalid value encountered in log10
#   flux_corr = np.log10(flux_line / flux_Hb) + 0.4 * excess * (av_line - av_Hb)
# /home/af/Desktop/fit_oh_cardoso_2025/fit_abundance/models.py:111: RuntimeWarning: divide by zero encountered in divide
#   ratios = weights[best] / weights
# h1 = 0.53, a1 = 0.43, b0 = 8.65
# NGC0309 completed.

# %%
print(results)
# Out:
# {'galaxy': 'NGC0309', 'b0': np.float64(8.653066586342554), 'eb0': np.float64(0.08474229516425365), 'a1': np.float64(0.42827258232592635), 'ea1': np.float64(0.21088546656939977), 'h1': np.float64(0.5284704930325224), 'eh1': np.float64(0.054096998150424166), 'a2': np.float64(-0.28674613153034034), 'ea2': np.float64(0.04091940843870819), 'h2': 0.0, 'eh2': 0.0, 'a3': 0.0, 'ea3': 0.0}
